# %% [markdown]
# # Made by XDBoobs team ;)

# %%
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV,  StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils import class_weight
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, precision_recall_curve, auc

# Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# ### Importing the dataset:

# %%
data = pd.read_csv("int20h-ds-test-dataset.csv")

# %% [markdown]
# ### Inspecting the data:

# %%
data.head()
# Out:
#                              userid user_state                  event_name  \
# 0  c95c777785faec8dd910d019d7278ebe         CA         Add Vehicle Success
# 1  c95c777785faec8dd910d019d7278ebe         CA           Add Vehicle Break
# 2  f344be2d9a042b7444f3cc5279e38ef1         FL             Calculator View
# 3  c95c777785faec8dd910d019d7278ebe         CA  Add Payment Method Success
# 4  e331ed81422d8fba55520a43a872e701         IL             Sign Up Success
#
#                                     event_attributes   event_created_date  \
# 0  {"Make":"Dodge","Model":"Caravan","Color":"Whi...  2022-01-16 17:03:04
# 1                                                 {}  2022-01-16 17:07:47
# 2                                                 {}  2022-01-16 17:16:25
# 3     {"Payment Method":"Credit","Tokenized Pay":""}  2022-01-16 17:24:22
# 4                                 {"Method":"Apple"}  2022-01-16 17:34:51
#
#   event_platform device_manufacture device_model
# 0        android            samsung     SM-N975U
# 1        android            samsung     SM-N975U
# 2        android            samsung    SM-G973U1
# 3        android            samsung     SM-N975U
# 4            ios              Apple   iPhone12,1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23357 entries, 0 to 23356
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userid              23357 non-null  object
#  1   user_state          23286 non-null  object
#  2   event_name          23357 non-null  object
#  3   event_attributes    23357 non-null  object
#  4   event_created_date  23357 non-null  object
#  5   event_platform      23357 non-null  object
#  6   device_manufacture  15847 non-null  object
#  7   device_model        15847 non-null  object
# dtypes: object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Oops... Some columns have missing values

# %%
columns_with_missing_data = data.columns[data.isnull().any()]

print("Columns with missing data: ")
for i, col in enumerate(columns_with_missing_data):
    print(i+1, col)
# Out:
# Columns with missing data:
# 1 user_state
# 2 device_manufacture
# 3 device_model

# %% [markdown]
# #### Percentage of missing data

# %%
print("Percentage of missing data: ")
data.isnull().sum() / data.shape[0] * 100
# Out:
# Percentage of missing data:
# userid                 0.000000
# user_state             0.303977
# event_name             0.000000
# event_attributes       0.000000
# event_created_date     0.000000
# event_platform         0.000000
# device_manufacture    32.153102
# device_model          32.153102
# dtype: float64

# %%
data[data['device_manufacture'].isnull()].head()
# Out:
#                               userid user_state            event_name  \
# 23  c664cc762bdcb88230b4b4f07e3b7d2e         CA    Transaction Refund
# 34  017f4557810b3ba165d2959c17b916b6         TX  Subscription Premium
# 72  0d51394c39dbf15021ccd09155ee6257         FL                 Order
# 73  0d51394c39dbf15021ccd09155ee6257         FL                 Order
# 74  0d51394c39dbf15021ccd09155ee6257         FL                 Order
#
#                                      event_attributes   event_created_date  \
# 23  {"Id":"708ee8f2012042b121be7dcdd6df256a","Amou...  2022-01-16 21:41:05
# 34  {"Start Date":"2022-01-16","Renewal Date":"202...  2022-01-17 00:04:58
# 72                      {"Premium Membership":"True"}  2022-01-15 09:23:48
# 73                      {"Premium Membership":"True"}  2022-01-15 09:23:48
# 74                      {"Premium Membership":"True"}  2022-01-15 10:16:12
#
#    event_platform device_manufacture device_model
# 23      outofband                NaN          NaN
# 34      outofband                NaN          NaN
# 72      outofband                NaN          NaN
# 73      outofband                NaN          NaN
# 74      outofband                NaN          NaN

# %% [markdown]
# #### Every single row that misses *device_manufacture* also doen't have *device_model* and vice versa:

# %%
print(data[(data['device_manufacture'].isna()) & (data['device_model'].isna() == False)].empty)
print(data[(data['device_model'].isna()) & (data['device_manufacture'].isna() == False)].empty)
# Out:
# True
# True

# %% [markdown]
# We can fill missing values in **device_manufacture** and **device_model** using information from same **userid**s

# %%
def fill_on_other_ids(data):
    null_data = data[data['device_manufacture'].isna()].copy()
    
    null_data['device_manufacture'] = null_data.apply(
        lambda row: (data[(data['userid'] == row['userid']) &
                        (data['device_manufacture'].isnull() == False)]['device_manufacture'].mode())[0]
                if (data[(data['userid'] == row['userid']) &
                        (data['device_manufacture'].isnull() == False)].empty == False)
                else row['device_manufacture'], axis=1)

    null_data['device_model'] = null_data.apply(
        lambda row: (data[(data['userid'] == row['userid']) &
                        (data['device_model'].isnull() == False)]['device_model'].mode())[0]
                if (data[(data['userid'] == row['userid']) &
                        (data['device_model'].isnull() == False)].empty == False)
                else row['device_model'], axis=1)

    data.update(null_data)
    
    return data

# %%
data = fill_on_other_ids(data)

# %%
print("Percentage of missing data: ")
data.isnull().sum() / data.shape[0] * 100
# Out:
# Percentage of missing data:
# userid                0.000000
# user_state            0.303977
# event_name            0.000000
# event_attributes      0.000000
# event_created_date    0.000000
# event_platform        0.000000
# device_manufacture    0.535171
# device_model          0.535171
# dtype: float64

# %% [markdown]
# Unfortunaly, some data is still missing :(

# %% [markdown]
# However, as far as we know only Apple manufactures ios devices

# %%
print(data[(data['event_platform'] == 'ios') & ((data['device_manufacture'] == 'Apple') == False)].empty)
# Out:
# True

# %%
data['device_manufacture'].unique()
# Out:
# array(['samsung', 'Apple', 'TCL', nan, 'motorola', 'Yulong', 'Wingtech',
#        'OnePlus', 'LGE', 'Google', 'realme', 'FIH', 'HMD Global',
#        'Xiaomi', 'BLU', 'vsmart', 'HUAWEI', 'OPPO', 'KYOCERA', 'Umx',
#        'HTC', 'Alcatel', 'ZTE'], dtype=object)

# %%
data.groupby(['device_manufacture']).size().sort_values(ascending = False) / data.groupby(['device_manufacture']).size().sum()
# Out:
# device_manufacture
# Apple         0.609031
# samsung       0.270876
# Google        0.038783
# motorola      0.024277
# LGE           0.022383
# OnePlus       0.009814
# HMD Global    0.008351
# TCL           0.007317
# Wingtech      0.004821
# BLU           0.000990
# FIH           0.000861
# vsmart        0.000560
# HUAWEI        0.000517
# Xiaomi        0.000344
# Umx           0.000301
# Yulong        0.000258
# realme        0.000258
# ZTE           0.000086
# OPPO          0.000043
# KYOCERA       0.000043
# HTC           0.000043
# Alcatel       0.000043
# dtype: float64

# %% [markdown]
# We may actually consider that all other devices that have **event_platform** = 'android' have **device_manufacture** = 'samsung'

# %%
def fill_device_manufacture(data):
    null_data = data[data['device_manufacture'].isna()].copy()
    
    null_data['device_manufacture'] = null_data.apply(lambda row: 'Apple'
            if (row['event_platform'] == 'ios')
            else 'samsung', axis=1)

    data.update(null_data)
    
    return data

# %%
data = fill_device_manufacture(data)

# %% [markdown]
# We will fill the rest of **device_model** missing values on with the most popular model of their manufacture

# %%
def fill_device_model(data):
    null_data = data[data['device_model'].isna()].copy()
    
    null_data['device_model'] = null_data.apply(
        lambda row: data[data['device_manufacture'] == row['device_manufacture']]['device_model'].mode()[0], axis=1)

    data.update(null_data)
    
    return data

# %%
data = fill_device_model(data)

# %% [markdown]
# Now we will deal with the **user_state** column

# %%
data[data['user_state'].isnull()].head()
# Out:
#                                userid user_state                  event_name  \
# 20   c5cf3fc44b606d4614a834a5306e9616        NaN             Sign Up Success
# 93   ed09ebeba14600a9ff4defc64e32503c        NaN             Sign Up Success
# 121  9182e94800ca0f8e9094ea3b8f5b169c        NaN             Sign Up Success
# 148  838db409e7565bfa896beff8bf7fe023        NaN             Sign Up Success
# 150  838db409e7565bfa896beff8bf7fe023        NaN  Email Confirmation Success
#
#         event_attributes   event_created_date event_platform  \
# 20    {"Method":"Email"}  2022-01-16 21:01:55        android
# 93    {"Method":"Email"}  2022-01-17 04:40:32            ios
# 121  {"Method":"Google"}  2022-01-15 14:46:05        android
# 148   {"Method":"Email"}  2022-01-17 15:43:30        android
# 150                   {}  2022-01-17 15:45:11        android
#
#     device_manufacture      device_model
# 20                 TCL             9032Z
# 93               Apple        iPhone11,6
# 121            samsung          SM-A426U
# 148           motorola  moto g stylus 5G
# 150           motorola  moto g stylus 5G

# %% [markdown]
# ### There is no other *user_state* information for *userid*s that have missing values:

# %%
for row in data[data['user_state'].isnull()]['userid']:
    state_data = data[(data['userid'] == row) &
                      (data['user_state'].isnull() == False)]
    if state_data.empty == False:
        print(state_data)

# %% [markdown]
# Let's try to find some correlation between **user_state** and **event_platform**. (**device_manufacture** and **device_model** are not appropriate for this because they have too much missing data themselves)

# %%
event_state_group = data[(data['user_state'].isnull() == False)].groupby(
    by=['user_state', 'event_platform']).size().unstack().fillna(0)
plt.figure(figsize=(10,15))
sns.heatmap(event_state_group, annot=True, fmt='g', cmap='coolwarm')
# Out:
# <AxesSubplot: xlabel='event_platform', ylabel='user_state'>

# %%
def fill_user_state(data):
    null_data = data[data['user_state'].isna()].copy()
    
    null_data['user_state'] = null_data.apply(lambda row: 'TX'
            if (row['event_platform'] == 'outofband')
            else 'CA', axis=1)
        
    data.update(null_data)
    
    return data

# %%
data = fill_user_state(data)

# %% [markdown]
# Now we need to classify the 'outofband' **event_platform** data

# %% [markdown]
# 1. Firstly, as we did before with **device_manufacture** and **device_model**, we will fill missing values using information from same **userid**s
# 2. We'll use the mode to fill any gaps that remain.

# %%
def fill_outofband(data):
    outofband_data = data[data['event_platform'] == 'outofband'].copy()
    
    outofband_data['event_platform'] = outofband_data.apply(
        lambda row: (data[(data['userid'] == row['userid']) &
                        (data['event_platform'] != 'outofband')]['event_platform'].mode())[0]
                if (data[(data['userid'] == row['userid']) &
                        (data['event_platform'] != 'outofband')].empty == False)
                else data['event_platform'].mode()[0], axis=1)
    
    data.update(outofband_data)
    return data

# %%
data = fill_outofband(data)

# %%
# percentage of missing data
data.isnull().sum() / data.shape[0]*100
# Out:
# userid                0.0
# user_state            0.0
# event_name            0.0
# event_attributes      0.0
# event_created_date    0.0
# event_platform        0.0
# device_manufacture    0.0
# device_model          0.0
# dtype: float64

# %% [markdown]
# Let's convert **event_created_date** from string to unix time format

# %%
data['event_created_date'] = data['event_created_date'].apply(lambda x: pd.to_datetime(x).value)

# %%
features = data.drop(['userid', 'event_name', 'event_attributes', 'event_created_date'], axis=1).columns

# %%
unique_users = data['userid'].unique()

# %%
user_properties = pd.DataFrame(index=unique_users, columns=features)

# %%
for user in unique_users:
    user_data = data[data['userid'] == user]
    for feature in features:
        user_properties.loc[user][feature] = data[data['userid'] == user][feature].mode()[0]

# %%
user_properties
# Out:
#                                  user_state event_platform device_manufacture  \
# c95c777785faec8dd910d019d7278ebe         CA        android            samsung
# f344be2d9a042b7444f3cc5279e38ef1         FL        android            samsung
# e331ed81422d8fba55520a43a872e701         IL            ios              Apple
# f6d930969a59cfb488ed4d126c7c856d         TX        android            samsung
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b         TX        android            samsung
# ...                                     ...            ...                ...
# 6ebd67ba68c521c86d797a1c439d6de9         FL        android            samsung
# 833489856a3cc8840d47a2c1cadda36d         CA        android             vsmart
# 679eba26c4e75e0afb178360becfa21b         CA        android             Google
# d46dcb2f00b6243de8714b979d524634         FL            ios              Apple
# 59e61796833e7e9edcb7796fac1688ba         FL            ios              Apple
#
#                                  device_model
# c95c777785faec8dd910d019d7278ebe     SM-N975U
# f344be2d9a042b7444f3cc5279e38ef1    SM-G973U1
# e331ed81422d8fba55520a43a872e701   iPhone12,1
# f6d930969a59cfb488ed4d126c7c856d     SM-A716U
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b     SM-A515F
# ...                                       ...
# 6ebd67ba68c521c86d797a1c439d6de9    SM-G998U1
# 833489856a3cc8840d47a2c1cadda36d        V350C
# 679eba26c4e75e0afb178360becfa21b     Pixel 3a
# d46dcb2f00b6243de8714b979d524634   iPhone13,4
# 59e61796833e7e9edcb7796fac1688ba   iPhone13,1
#
# [3540 rows x 4 columns]

# %% [markdown]
# Now we will need to deal with **event_name** and **event_attributes**

# %%
data.sort_values(['userid', 'event_created_date'], inplace=True)
data.head(25)
# Out:
#                                  userid user_state  \
# 456    0006869712ec9841dc36234bce245203         MD
# 457    0006869712ec9841dc36234bce245203         MD
# 458    0006869712ec9841dc36234bce245203         MD
# 459    0006869712ec9841dc36234bce245203         MD
# 460    0006869712ec9841dc36234bce245203         MD
# 5238   0006869712ec9841dc36234bce245203         MD
# 2870   000a59897372c5e3c147b15685fefc65         CA
# 2086   001244c572f1a681553bc045a378cacf         FL
# 4529   0032cb66b99f6baef57ec2aa04a9277f         CA
# 12497  003f57fe2631ade57a86f6a2b96bb20c         CA
# 12499  003f57fe2631ade57a86f6a2b96bb20c         CA
# 12502  003f57fe2631ade57a86f6a2b96bb20c         CA
# 12503  003f57fe2631ade57a86f6a2b96bb20c         CA
# 12504  003f57fe2631ade57a86f6a2b96bb20c         CA
# 5721   00596aa4edee32815aaf4aad659c484e         CA
# 5722   00596aa4edee32815aaf4aad659c484e         CA
# 5723   00596aa4edee32815aaf4aad659c484e         CA
# 5724   00596aa4edee32815aaf4aad659c484e         CA
# 5725   00596aa4edee32815aaf4aad659c484e         CA
# 9656   00596aa4edee32815aaf4aad659c484e         CA
# 9657   00596aa4edee32815aaf4aad659c484e         CA
# 10750  00596aa4edee32815aaf4aad659c484e         CA
# 13264  006264e968756ad7036980576bc3b4a5         TX
# 10389  0079e6902320d6771024a236ab801f2e         TX
# 17069  0079e6902320d6771024a236ab801f2e         TX
#
#                                 event_name  \
# 456             Add Payment Method Success
# 457                   Subscription Premium
# 458    Account History Transaction Details
# 459    Account History Transaction Details
# 460                    Add Vehicle Success
# 5238            Subscription Premium Renew
# 2870                       Sign Up Success
# 2086                       Sign Up Success
# 4529                       Sign Up Success
# 12497                      Sign Up Success
# 12499                  Add Vehicle Success
# 12502           Account Setup Profile Skip
# 12503           Account Setup Profile Skip
# 12504                      Calculator View
# 5721                       Sign Up Success
# 5722                   Add Vehicle Success
# 5723            Add Payment Method Success
# 5724            Add Payment Method Success
# 5725                  Subscription Premium
# 9656                                 Order
# 9657                                 Order
# 10750                                Order
# 13264                      Sign Up Success
# 10389                      Sign Up Success
# 17069                             Sign Out
#
#                                         event_attributes   event_created_date  \
# 456        {"Payment Method":"Debit","Tokenized Pay":""}  1642618065000000000
# 457    {"Start Date":"2022-01-19","Renewal Date":"202...  1642618081000000000
# 458    {"Navigated From":"Account History","Status":"...  1642618088000000000
# 459    {"Navigated From":"Account History","Status":"...  1642618124000000000
# 460    {"Make":"Chevrolet","Model":"Express 3500","Co...  1642618234000000000
# 5238   {"Start Date":"2022-02-20","Renewal Date":"202...  1645233136000000000
# 2870                                  {"Method":"Apple"}  1644191488000000000
# 2086                                 {"Method":"Google"}  1643201345000000000
# 4529                                  {"Method":"Apple"}  1644633125000000000
# 12497                                 {"Method":"Apple"}  1647368642000000000
# 12499  {"Make":"Ford","Model":"C-Max Energi","Tempora...  1647368758000000000
# 12502                               {"Screen":"Address"}  1647368866000000000
# 12503                          {"Screen":"Phone number"}  1647368868000000000
# 12504                                                 {}  1647368979000000000
# 5721                                 {"Method":"Google"}  1645039014000000000
# 5722   {"Make":"Chrysler","Model":"300","Color":"Silv...  1645039383000000000
# 5723      {"Payment Method":"PayPal","Tokenized Pay":""}  1645040206000000000
# 5724      {"Payment Method":"PayPal","Tokenized Pay":""}  1645040271000000000
# 5725   {"Start Date":"2022-02-16","Renewal Date":"202...  1645040332000000000
# 9656                       {"Premium Membership":"True"}  1646162349000000000
# 9657                       {"Premium Membership":"True"}  1646162415000000000
# 10750                      {"Premium Membership":"True"}  1646491529000000000
# 13264                                 {"Method":"Email"}  1647524851000000000
# 10389                                {"Method":"Google"}  1646871337000000000
# 17069                                  {"Type":"Manual"}  1648482462000000000
#
#       event_platform device_manufacture device_model
# 456          android            samsung     SM-A716U
# 457          android            samsung     SM-A716U
# 458          android            samsung     SM-A716U
# 459          android            samsung     SM-A716U
# 460          android            samsung     SM-A716U
# 5238         android            samsung     SM-A716U
# 2870             ios              Apple   iPhone11,6
# 2086         android            samsung     SM-G780G
# 4529             ios              Apple   iPhone14,3
# 12497            ios              Apple   iPhone13,4
# 12499            ios              Apple   iPhone13,4
# 12502            ios              Apple   iPhone13,4
# 12503            ios              Apple   iPhone13,4
# 12504            ios              Apple   iPhone13,4
# 5721         android            samsung     SM-N976U
# 5722         android            samsung     SM-N976U
# 5723         android            samsung     SM-N976U
# 5724         android            samsung     SM-N976U
# 5725         android            samsung     SM-N976U
# 9656         android            samsung     SM-N976U
# 9657         android            samsung     SM-N976U
# 10750        android            samsung     SM-N976U
# 13264            ios              Apple   iPhone11,6
# 10389        android            samsung    SM-S124DL
# 17069        android            samsung    SM-S124DL

# %%
unique_combinations = []

# %% [markdown]
# Get all the unique feature combinations

# %%
for user in unique_users:
    user_data = data[data['userid'] == user]
    for item in user_data.iloc:
        event = item['event_name']
        event_attributes = json.loads(item['event_attributes'])
        
        if len(event_attributes.keys()) > 0:
            for key in event_attributes.keys():
                if key not in ['Id', 'Amount', 'Start Date', 'Renewal Date', 'End Date']:
                    combination = event + ' ' + key + ' ' + event_attributes[key]
                elif key == 'Amount':
                    combination = event + ' ' + key
                unique_combinations.append(combination)
        else:
            unique_combinations.append(event)

# %%
unique_combinations = list(set(unique_combinations))
unique_combinations
# Out:
# ['Add Vehicle Success Make RAM',
#  'Add Vehicle Success Model RAV4 Hybrid',
#  'Add Vehicle Success Model Q60',
#  'Add Vehicle Success Model Camry',
#  'Add Vehicle Success Model Wrangler',
#  'Add Vehicle Success Model Armada',
#  'Add Vehicle Success Make Honda',
#  'Add Vehicle Success Make Kawasaki ',
#  'Add Vehicle Success Model GLA-Class',
#  'Order Premium Membership True',
#  'Add Vehicle Success Make Pontiac',
#  'Add Vehicle Success Model CT Hybrid',
#  'Account Setup Profile Skip Screen Phone Number',
#  'Account Setup Profile Skip Screen Phone number exists',
#  'Account History Transaction Details Type Forced Payment',
#  'Add Vehicle Success Model Highlander Hybrid',
#  'Add Vehicle Success Make Genesis',
#  'Add Vehicle Success Year 2012',
#  'Add Vehicle Success Model C-Max Hybrid',
#  'Add Vehicle Success Model Savana 2500',
#  'Transaction Refund Amount',
#  'Add Vehicle Success Rental State NY',
#  'Add Vehicle Success Model RAV4 Prime',
#  'Add Vehicle Success Make Granville',
#  'Add Vehicle Success Model 579',
#  'Add Vehicle Success Model Forte Koup',
#  'Add Payment Method Failed Payment Method Google Pay',
#  'Add Vehicle Success Model 2-series',
#  'Add Vehicle Success Make Jeep',
#  'Add Vehicle Success Model X6M',
#  'Add Vehicle Success Model 328',
#  'Add Vehicle Success Model Sierra 2500HD',
#  'Add Vehicle Success Model Voyager',
#  'Add Vehicle Success Model Kizashi',
#  'Add Vehicle Success Model Silverado 3500HD',
#  'Add Vehicle Success Model Milan',
#  'Add Vehicle Success Model Outlander Sport',
#  'Add Vehicle Success Make Kenworth',
#  'Add Vehicle Success Model Baystar',
#  'Add Vehicle Success Model 1500',
#  'Add Vehicle Success Model Niro',
#  'Add Vehicle Success Make Dodge',
#  'Add Vehicle Success Model Patriot',
#  'Add Vehicle Success Make Mercedes-Benz',
#  'Email Confirmation Success Required true',
#  'Add Vehicle Success Year 2022',
#  'Add Vehicle Success Model Maxima',
#  'Add Vehicle Success Model Silverado 1500HD',
#  'Add Vehicle Success Model F-250',
#  'Add Vehicle Success Model RX',
#  'Add Vehicle Success Model Freestar',
#  'Add Vehicle Success Year 2016',
#  'Add Vehicle Success Model IS 250',
#  'Add Vehicle Success Color Gold',
#  'Add Vehicle Success Make Grand Design ',
#  'Add Vehicle Success Model GLK-Class',
#  'Subscription Premium Membership Type Monthly',
#  'Add Vehicle Success Make Chrysler',
#  'Add Vehicle Success Model XJ',
#  'Add Vehicle Success Model Telluride',
#  'Add Vehicle Success Model Expedition',
#  'Add Vehicle Success Model GS',
#  'Add Vehicle Success Model ProMaster City',
#  'Add Vehicle Success Make Newmar',
#  'Add Vehicle Success Model NPR HD',
#  'Add Vehicle Success Model Murano',
#  'Add Payment Method Success Payment Method Venmo',
#  'Add Vehicle Success Color Orange',
#  'Add Vehicle Success Year 1991',
#  'Add Payment Method Failed Tokenized Pay Google Pay',
#  'Add Vehicle Break',
#  'Add Vehicle Success Model 7',
#  'Add Vehicle Success Model F-350 SD DRW',
#  'Add Vehicle Success Model Cruze Limited',
#  'Add Vehicle Success Model C-Class',
#  'Add Vehicle Success Model Eos',
#  'Add Vehicle Success Model F-150 Heritage',
#  'Add Vehicle Success Model 4D',
#  'Add Vehicle Success Model G8',
#  'Chat Conversation Opened Transaction type AutoPayment',
#  'Add Vehicle Success Year 1997',
#  'Add Payment Method Failed Error Message Postal code can only contain letters, numbers, spaces, and hyphens.',
#  'Add Vehicle Success Model Mustang',
#  'Add Vehicle Success Model Golf',
#  'Subscription Premium Renew Membership Type Yearly',
#  'Add Payment Method Failed Error Code ERROR-16010',
#  'Add Vehicle Success Model 3-series',
#  'Add Vehicle Success Model Tercel',
#  'Add Vehicle Success Year 2004',
#  'Add Vehicle Success Model X5',
#  'Add Vehicle Success Make Porsche',
#  'Add Vehicle Success Model Avenger',
#  'Add Vehicle Success Model iA',
#  'Add Vehicle Success Model Spark',
#  'Add Vehicle Success Model MPV',
#  'Add Vehicle Success Make Nissan ',
#  'Add Vehicle Success Model xA',
#  'Add Vehicle Success Model Malibu Hybrid',
#  'Add Vehicle Success Model 540',
#  'Add Vehicle Success Model Suburban',
#  'Add Vehicle Success Model MKX',
#  'Add Vehicle Success Make Frieghtliner',
#  'Add Vehicle Success Model NX',
#  'Add Vehicle Success Model Z4 Roadster',
#  'Add Vehicle Success Model Encore GX',
#  'Chat Conversation Opened Transaction type ',
#  'Add Vehicle Success Model Escape Hybrid',
#  'Add Vehicle Success Model F-350 SD',
#  'Add Vehicle Success Model G Sedan',
#  'Add Vehicle Success Model Yukon XL',
#  'Add Vehicle Success Model Cutlass',
#  'Add Vehicle Success Year 2001',
#  'Add Vehicle Success Model Explorer Sport',
#  'Add Vehicle Success Model A4 Avant',
#  'Add Vehicle Success Model Bolt EV',
#  'Add Vehicle Success Model E',
#  'Add Vehicle Success Model Santa Fe',
#  'Add Vehicle Success Model tC',
#  'Add Vehicle Success Model Prius C',
#  'Add Vehicle Success Model LT',
#  'Add Vehicle Success Model NX Hybrid',
#  'Add Vehicle Success Make Lincoln',
#  'Add Vehicle Success Model Prius Hybrid',
#  'Add Vehicle Success Model NV200',
#  'Add Vehicle Success Model Passat',
#  'Add Vehicle Success Model Stealth',
#  'Add Payment Method Success Promo code VEHICLEVIRGINS',
#  'Add Vehicle Success Make GMC',
#  'Add Vehicle Success Make BMW',
#  'Add Vehicle Success Model Express 3500',
#  'Add Vehicle Success Model DeVille',
#  'Add Vehicle Success Model Civic Hatchback',
#  'Add Vehicle Success Model C300',
#  'Add Vehicle Success Model Reflection 5th Wheel',
#  'Add Vehicle Success Model E-150 Wagon',
#  'Sign Out Type Manual',
#  'Account History Transaction Details Type Violation Transaction',
#  'Add Vehicle Success Model equinox',
#  'Add Vehicle Success Make Land Rover',
#  'Sign Up Success Method Google',
#  'Add Vehicle Success Model Sedona',
#  'Add Vehicle Success Model A4',
#  'Add Vehicle Success Model Town & Country',
#  'Add Vehicle Success Model QX60',
#  'Add Vehicle Success Model RX Hybrid',
#  'Add Payment Method Success Promo code GRIDWISE',
#  'Add Vehicle Success Model Verano',
#  'Add Payment Method Failed Tokenized Pay Apple Pay',
#  'Add Vehicle Success Make Toyota',
#  'Add Vehicle Success Model Q7',
#  'Add Vehicle Success Model CLK',
#  'Add Vehicle Success Make Subaru',
#  'Add Vehicle Success Model X3',
#  'Add Vehicle Success Model Sd',
#  'Add Vehicle Success Make Ford F 550',
#  'Add Vehicle Success Model TSX',
#  'Add Vehicle Success Model V60',
#  'Add Vehicle Success Model HR-V',
#  'Add Vehicle Success Model Avalon',
#  'Sign Up Success Method Email',
#  'Add Vehicle Success Year 2010',
#  'Add Vehicle Success Model Aveo',
#  'Add Vehicle Success Model Forrester',
#  'Sign Up Success Method Facebook',
#  'Add Vehicle Success Model Soul',
#  'Add Vehicle Success Model Sentra',
#  'Add Vehicle Success Model City Express',
#  'Sign Out Type Auto',
#  'Add Vehicle Success Model X1',
#  'Add Payment Method Failed Error Code ERROR-NaN10',
#  'Add Vehicle Success Model Navigator L',
#  'Add Vehicle Success Make Hyundai',
#  'Add Vehicle Success Model Range Rover Evoque',
#  'Add Vehicle Success Model Lancer',
#  'Add Vehicle Success Model Element',
#  'Calculator View',
#  'Add Vehicle Success Make Mercury',
#  'Add Vehicle Success Make Hino',
#  'Add Vehicle Success Model Civic',
#  'Add Vehicle Success Model Dakota',
#  'Add Vehicle Success Year 2023',
#  'Add Vehicle Success Color Other',
#  'Add Vehicle Success Model Terrain',
#  'Sign Up Error Description Cognito Unknown Error; description: Sign-in with web UI failed',
#  'Chat Conversation Opened Transaction type ForcedPayment',
#  'Add Vehicle Success Model MAZDA3',
#  'Add Vehicle Success Year 2005',
#  'Add Vehicle Success Model GLE-Class',
#  'Add Vehicle Success Model XT5',
#  'Add Vehicle Success Make Peterbilt',
#  'Add Vehicle Success Model Optima Hybrid',
#  'Add Vehicle Success Model Transit Passenger',
#  'Add Vehicle Success Model 4300',
#  'Add Vehicle Success Model Tucson',
#  'Add Vehicle Success Model F-150',
#  'Add Vehicle Success Model Tundra',
#  'Add Vehicle Success Model Silverado',
#  'Add Vehicle Failed Error Message The operation couldn’t be completed. (Company.ErrorResponse error 0.)',
#  'Add Vehicle Success Make Saab',
#  'Add Vehicle Success Model Cadenza',
#  'Account History Transaction Details Status Paid',
#  'Add Payment Method Failed Error Message CVV must be 4 digits for American Express and 3 digits for other card types.',
#  'Add Vehicle Success Model SRX',
#  'Add Vehicle Success Year 1985',
#  'Chat Conversation Opened Transaction type OrderAlert',
#  'Add Vehicle Success Color Green',
#  'Add Vehicle Success Model Challenger',
#  'Add Vehicle Success Model Venza',
#  'Add Vehicle Success Year 2009',
#  'Add Vehicle Success Model Accord',
#  'Add Vehicle Success Model Silverado 2500HD',
#  'Add Vehicle Success Year 1998',
#  'Add Vehicle Success Model Coupe',
#  'Add Vehicle Success Model Camry Hybrid',
#  'Account History Transaction Details Navigated From Account History',
#  'Add Vehicle Success Year 2007',
#  'Add Vehicle Success Rental State KY',
#  'Add Vehicle Success Rental State IL',
#  'Calculator Used',
#  'Add Vehicle Success Model Renegade',
#  'Add Vehicle Success Model Continental',
#  'Add Vehicle Success Model Corolla Hybrid',
#  'Add Vehicle Success Year 2008',
#  'Add Vehicle Success Rental State OK',
#  'Add Vehicle Success Model 600LT',
#  'Add Vehicle Success Model Regal',
#  'Add Vehicle Success Make Fleetwood',
#  'Add Vehicle Success Temporary true',
#  'Add Vehicle Success Model Ion',
#  'Add Vehicle Success Make Acura',
#  'Add Vehicle Success Model Xterra',
#  'Add Vehicle Success Model 550',
#  'Add Vehicle Success Model TL',
#  'Add Vehicle Success Model 320',
#  'Add Vehicle Success Model Titan XD',
#  'Add Vehicle Success Model International',
#  'Add Vehicle Success Model Avalon Hybrid',
#  'Add Vehicle Success Model Dart',
#  'Add Vehicle Success Model Alpina V8',
#  'Add Vehicle Success Make tiffin',
#  'Add Vehicle Success Model Elantra',
#  'Sign Up Success Method Apple',
#  'Add Vehicle Success Model Altima',
#  'Add Vehicle Success Model Ioniq Hybrid',
#  'Account Setup Profile Skip Screen Address Details',
#  'Add Vehicle Success Make Forest River',
#  'Add Vehicle Success Year 2013',
#  'Add Vehicle Success Make Audi',
#  'Add Vehicle Success Model IS',
#  'Add Vehicle Success Model Aviator',
#  'Add Vehicle Success Color Yellow',
#  'Add Vehicle Success Model ES',
#  'Add Vehicle Success Make Fiat',
#  'Add Vehicle Success Model Atlas',
#  'Account Setup Profile Skip Screen Phone number',
#  'Add Vehicle Success Model Expedition MAX',
#  'Add Vehicle Success Model Polestar 2',
#  'Add Vehicle Success Model Stinger',
#  'Add Vehicle Success Model FJ Cruiser',
#  'Add Vehicle Success Model GLC-Class',
#  'Add Vehicle Success Model Cobalt',
#  'Add Vehicle Success Model Super Duty',
#  'Subscription Premium Renew Membership Type Monthly',
#  'Add Vehicle Success Model Avalanche 1500',
#  'Add Vehicle Success Model Range Rover',
#  'Sign Up Error Description Email not provided',
#  'Add Vehicle Success Model Convertible',
#  'Add Vehicle Success Model E-350',
#  'Add Vehicle Success Model Fusion Hybrid',
#  'Add Vehicle Failed Error Code ERROR-NaN10',
#  'Add Vehicle Success Year 2002',
#  'Add Vehicle Success Make Suzuki',
#  'Add Vehicle Success Model Caliber',
#  'Add Vehicle Success Model K5',
#  'Calculator Used Google Map Installed true',
#  'Add Vehicle Success Model RDX',
#  'Account History Transaction Details Status Pending',
#  'Add Vehicle Success Model ILX',
#  'Add Vehicle Success Model Fiesta',
#  'Calculator Used Selected Route Type Fastest',
#  'Add Vehicle Success Year 2015',
#  'Add Vehicle Success Make 2015',
#  'Add Vehicle Success Year 2017',
#  'Add Vehicle Success Model A3',
#  'Add Vehicle Success Model Eclipse Cross',
#  'Add Vehicle Success Model Forte',
#  'Add Vehicle Success Make 2007',
#  'Add Vehicle Success Model Ram',
#  'Add Vehicle Success Rental State TX',
#  'Chat Conversation Opened From Deeplink',
#  'Add Vehicle Success Model Cayman',
#  'Subscription Premium Cancel',
#  'Add Vehicle Success Model Pacifica',
#  'Add Vehicle Success Model Impala',
#  'Add Vehicle Success Color Beige',
#  'Add Vehicle Success Model XV Crosstrek',
#  'Add Vehicle Success Model Malibu',
#  'Add Vehicle Success Model Silverado Classic 2500',
#  'Account History Transaction Details Type Order',
#  'Add Vehicle Success Model G70',
#  'Add Vehicle Success Make Infiniti',
#  'Add Vehicle Success Model Versa',
#  'Add Vehicle Success Model Juke',
#  'Add Vehicle Success Year 1994',
#  'Add Vehicle Success Make Lexus',
#  'Add Vehicle Success Make Mini',
#  'Add Vehicle Success Model M-Class',
#  'Add Vehicle Success Model E350',
#  'Add Vehicle Success Model CX-9',
#  'Add Vehicle Success Model XT4',
#  'Add Vehicle Success Model Virago',
#  'Add Vehicle Success Model TLX',
#  'Add Vehicle Success Model Acadia',
#  'Add Vehicle Success Model MAZDA6',
#  'Add Vehicle Success Model CX-5',
#  'Add Vehicle Success Model CLA-Class',
#  'Add Vehicle Success Make Volvo',
#  'Add Vehicle Success Model Wrangler Unlimited',
#  'Add Vehicle Success Model 4Runner',
#  'Add Vehicle Success Model E-Class',
#  'Add Vehicle Success Model Colorado',
#  'Add Vehicle Success Model Sprinter Cargo Van',
#  'Add Vehicle Success Model bike',
#  'Chat Conversation Opened',
#  'Add Vehicle Success Model Countryman',
#  'Add Vehicle Success Model Rogue SV',
#  'Add Vehicle Success Make Volkswagen',
#  'Add Vehicle Success Model Sienna',
#  'Account History Transaction Details Type Refund Transaction',
#  'Add Vehicle Success Model LeSabre',
#  'Add Vehicle Success Rental State CA',
#  'Add Vehicle Success Model Elantra Touring',
#  'Add Vehicle Success Model c320',
#  'Add Vehicle Success Model MH',
#  'Add Vehicle Success Model Aura',
#  'Add Vehicle Success Model Cube',
#  'Add Vehicle Success Year 2006',
#  'Sign Up Error Method Facebook',
#  'Add Vehicle Failed Error Message Start Date (in User Timezone) can not be less than Expected Activation Time For Rental State (2022-03-10T17:02:16.778Z)',
#  'Add Vehicle Success Model ATS',
#  'Add Vehicle Success Rental State FL',
#  'Add Vehicle Success Model Explorer',
#  'Add Vehicle Success Model DTS',
#  'Add Vehicle Success Model Mirage',
#  'Add Vehicle Success Model Taurus X',
#  'Add Vehicle Success Model Camaro',
#  'Add Vehicle Success Model Cooper',
#  'Add Vehicle Success Model GT',
#  'Sign Up Error Description Unexpected Error',
#  'Add Vehicle Success Model F-250 SD',
#  'Add Vehicle Success Model 5-series',
#  'Add Vehicle Success Model Pilot',
#  'Add Vehicle Success Temporary false',
#  'Add Vehicle Success Make Oldsmobile',
#  'Add Vehicle Success Model Liberty',
#  'Add Vehicle Success Model xB',
#  'Add Vehicle Success Model GTI',
#  'Add Vehicle Success Model 911',
#  'Add Vehicle Success Model Forester',
#  'Add Vehicle Success Model Jetta SportWagen',
#  'Add Vehicle Success Year 2011',
#  'Add Vehicle Success Model WRX',
#  'Add Vehicle Success Model Yaris',
#  'Add Payment Method Failed Payment Method Credit Card',
#  'Add Vehicle Success Model XC60 T6 AWD',
#  'Add Vehicle Success Model LS',
#  'Add Vehicle Success Make Tesla',
#  'Add Vehicle Success Model Genesis Coupe',
#  'Chat Conversation Opened Transaction type ManualPayment',
#  'Add Vehicle Success Model Sportage',
#  'Add Vehicle Success Model Sonata',
#  'Add Vehicle Success Make Polestar',
#  'Add Payment Method Success Tokenized Pay Apple Pay',
#  'Add Vehicle Success Year 2014',
#  'Add Vehicle Success Model Nitro',
#  'Add Vehicle Success Model Doubonaire ',
#  'Add Vehicle Success Model Crown Victoria',
#  'Add Vehicle Success Make Scion',
#  'Add Vehicle Success Model Fit',
#  'Add Vehicle Success Make chevy',
#  'Add Payment Method Failed Error Message Card is debit but credit is required.',
#  'Add Vehicle Success Model Impreza',
#  'Add Vehicle Success Model Providence',
#  'Add Vehicle Success Model Qx56',
#  'Add Vehicle Success Model Cavalier',
#  'Add Vehicle Success Model Prius',
#  'Add Vehicle Success Model Cruze',
#  'Add Vehicle Success Color Red',
#  'Add Vehicle Success Model MAZDA2',
#  'Add Vehicle Success Make Mclaren',
#  'Add Vehicle Success Model Corolla',
#  'Add Vehicle Success Model Ram 1500',
#  'Add Vehicle Success Model Kicks',
#  'Add Vehicle Success Model Yukon',
#  'Account Setup Profile Skip Screen Address',
#  'Add Vehicle Success Make international ',
#  'Add Vehicle Success Model Trax',
#  'Account Setup Profile Skip Screen Address details',
#  'Add Vehicle Success Year 2000',
#  'Chat Conversation Started',
#  'Add Vehicle Success Make Ford',
#  'Add Vehicle Success Model A4 2.0T',
#  'Add Vehicle Success Model 200',
#  'Add Vehicle Success Model Envision',
#  'Add Vehicle Success Model Caravan',
#  'Add Vehicle Success Model M',
#  'Add Vehicle Success Model Edge',
#  'Add Vehicle Success Model Commander',
#  'Add Vehicle Success Model E-150',
#  'Add Payment Method Success Promo code LUCKYDAY',
#  'Add Vehicle Success Model MAZDA5',
#  'Add Vehicle Success Model Blazer',
#  'Add Vehicle Success Model Q5',
#  'Reset Password Set',
#  'Add Vehicle Success Make freightliner',
#  'Add Vehicle Success Model Hino',
#  'Add Vehicle Success Make Kia',
#  'Add Vehicle Success Model Town Car',
#  'Add Vehicle Success Model LX',
#  'Add Vehicle Success Model Hond odissei mini wa',
#  'Add Vehicle Success Model Sprinter 2500 Cargo Van',
#  'Add Vehicle Success Make Nissan',
#  'Add Vehicle Success Model A5 Cabriolet',
#  'Add Vehicle Success Model 2500',
#  'Add Vehicle Success Model Civic Coupe ',
#  'Add Vehicle Success Make Buick',
#  'Add Payment Method Failed Tokenized Pay ',
#  'Account Setup Skip',
#  'Add Vehicle Success Model Journey',
#  'Add Vehicle Success Model Cayenne',
#  'Add Vehicle Success Model Grand Caravan',
#  'Add Vehicle Success Model EcoSport',
#  'Add Vehicle Success Model Accent',
#  'Add Vehicle Success Model Ridgeline',
#  'Add Vehicle Success Model CR-V',
#  'Add Vehicle Success Model Outlander',
#  'Add Vehicle Success Model Encore',
#  'Add Vehicle Success Model Tacoma',
#  'Add Vehicle Success Make International',
#  'Chat Conversation Opened From Transaction Details',
#  'Add Vehicle Success Model Sonata Hybrid',
#  'Account History Transaction Details Status Overdue',
#  'Add Vehicle Success Model New Beetle',
#  'Add Vehicle Success Make Alfa Romeo',
#  'Add Vehicle Success Make Saturn',
#  'Add Vehicle Success Year 1983',
#  'Sign Up Error Description An account with that email already exists.',
#  'Add Vehicle Success Model Rogue Sport',
#  'Add Vehicle Success Model 500C',
#  'Add Vehicle Success Model 300',
#  'Chat Conversation Opened From Dashboard',
#  'Add Vehicle Success Model Suburban 1500',
#  'Add Vehicle Success Model Outback',
#  'Add Vehicle Success Model Model Y',
#  'Add Vehicle Success Color Blue',
#  'Add Vehicle Success Model MDX',
#  'Add Vehicle Success Year 2019',
#  'Calculator Used Selected Route Type Cheapest',
#  'Add Vehicle Success Model Corolla Hatchback',
#  'Add Vehicle Success Model Pathfinder',
#  'Add Vehicle Success Rental State ',
#  'Add Vehicle Success Model Rogue Select',
#  'Add Vehicle Success Model Silverado 1500 LD',
#  'Chat Conversation Opened Transaction Type Pro Plan Subscription',
#  'Add Vehicle Success Make Merecedes-benz',
#  'Add Vehicle Success Model STS',
#  'Add Vehicle Success Model C1500',
#  'Add Vehicle Success Model gsxr 1000',
#  'Add Vehicle Success Model Excursion',
#  'Add Vehicle Success Model Focus SE',
#  'Add Vehicle Success Model 1500 Classic',
#  'Add Vehicle Success Model Forenza',
#  'Add Vehicle Success Model  Bronco',
#  'Add Vehicle Failed Error Code ERROR-15110',
#  'Add Vehicle Success Model Legacy',
#  'Add Vehicle Success Make Mazda',
#  'Add Vehicle Success Model Matrix',
#  'Add Vehicle Success Model SLC-Class',
#  'Add Vehicle Success Model 1-series',
#  'Add Vehicle Success Model Atlas Cross Sport',
#  'Add Vehicle Success Model Fusion Energi',
#  'Add Vehicle Success Model W900',
#  'Add Payment Method Failed Error Message Payment method failed verification.',
#  'Add Vehicle Success Model XC70 T6 AWD',
#  'Add Vehicle Success Model CR-V Hybrid',
#  'Add Vehicle Success Model Ascent',
#  'Add Vehicle Success Rental state CA',
#  'Add Vehicle Success Model Accord Hybrid',
#  'Add Vehicle Success Model Stratus',
#  'Add Vehicle Success Model CX-3',
#  'Add Vehicle Success Model moving truck',
#  'Add Vehicle Success Model Escape',
#  'Add Vehicle Success Model Navigator',
#  'Add Vehicle Success Model Metris Passenger Van',
#  'Add Vehicle Success Model Panamera',
#  'Add Vehicle Success Model Tribute',
#  'Add Vehicle Success Model Jetta',
#  'Add Vehicle Success Model Vibe',
#  'Add Vehicle Success Model 500X',
#  'Add Vehicle Success Model MKC',
#  'Add Vehicle Success Model Focus',
#  'Sign Up Error Method Google',
#  'Add Vehicle Success Model Captiva Sport',
#  'Add Vehicle Success Model C40',
#  'Add Vehicle Success Model 528',
#  'Add Vehicle Success Model Touareg',
#  'Add Vehicle Success Model 370Z',
#  'Add Vehicle Success Model cascadia',
#  'Add Vehicle Success Color White',
#  'Account History Transaction Details Type Manual Payment',
#  'Add Vehicle Success Model Escalade',
#  'Account Setup Profile Skip Screen Name',
#  'Add Vehicle Success Model VUE',
#  'Add Vehicle Success Make Take',
#  'Add Vehicle Success Model Civic Hybrid',
#  'Add Vehicle Success Model C-Max Energi',
#  'Account History Transaction Details Type Pro Plan Subscription',
#  'Add Vehicle Success Model Cascadia',
#  'Add Vehicle Success Color Gray',
#  'Add Vehicle Success Model Prelude',
#  'Add Vehicle Success Model 330',
#  'Add Vehicle Success Model Giulia',
#  'Add Vehicle Success Year 2020',
#  'Add Vehicle Success Model Hombre',
#  'Add Vehicle Success Rental State NJ',
#  'Add Vehicle Success Model SC',
#  'Add Vehicle Success Model Tiguan',
#  'Add Vehicle Success Model Gladiator',
#  'Sign Up Error Method Email',
#  'Add Vehicle Success Make Freightliner',
#  'Add Vehicle Success Model Econoline',
#  'Add Vehicle Success Model Grand Vitara',
#  'Add Vehicle Success Model Pathfinder ',
#  'Add Vehicle Success Model Veloster',
#  'Add Payment Method Success Promo code ',
#  'Chat Conversation Opened Transaction Type ',
#  'Chat Conversation Opened From ',
#  'Add Vehicle Success Make Isuzu',
#  'Add Vehicle Success Model Volt',
#  'Add Vehicle Success Model Cherokee',
#  'Add Vehicle Success Model Santa Fe Sport',
#  'Add Vehicle Success Model LaCrosse',
#  'Add Vehicle Success Model Insight Hybrid',
#  'Add Vehicle Success Model Genesis',
#  'Calculator Used Google Map Installed false',
#  'Add Vehicle Success Model A5',
#  'Add Vehicle Success Model Honda Civic EX ',
#  'Add Vehicle Success Model C',
#  'Add Vehicle Success Model Enclave',
#  'Add Vehicle Success Model MKS',
#  'Add Vehicle Success Model Optima',
#  'Add Vehicle Success Model Camry Solara',
#  'Add Vehicle Success Model ES Hybrid',
#  'Add Vehicle Success Model 530',
#  'Add Vehicle Success Model M6',
#  'Add Vehicle Success Model Crosstrek',
#  'Add Vehicle Success Model Toyota',
#  'Account History Transaction Details Type Promotion',
#  'Add Vehicle Success Model GLE-Class Coupe',
#  'Add Vehicle Success Model XC90',
#  'Add Vehicle Success Model Traverse',
#  'Add Vehicle Success Model G Coupe',
#  'Add Vehicle Success Make Mitsubishi',
#  'Add Vehicle Success Rental state ',
#  'Add Vehicle Success Model Model 3',
#  'Add Vehicle Success Model CC',
#  'Add Vehicle Success Model Macan',
#  'Add Vehicle Success Model S',
#  'Add Vehicle Success Model Altime Coupe',
#  'Order Premium Membership False',
#  'Add Vehicle Success Model Thruxton 1200R',
#  'Add Vehicle Success Model M3',
#  'Add Vehicle Success Model XE',
#  'Add Vehicle Success Color Black',
#  'Add Vehicle Success Model Avalanche 2500',
#  'Add Vehicle Success Model 535',
#  'Add Vehicle Success Make Triumph',
#  'Add Vehicle Success Rental State DE',
#  'Add Vehicle Success Model G Convertible',
#  'Add Vehicle Success Model Fusion',
#  'Add Vehicle Success Color Silver',
#  'Add Vehicle Success Model Compass',
#  'Add Vehicle Success Color Brown',
#  'Add Vehicle Success Model Sequoia',
#  'Add Payment Method Success Payment Method PayPal',
#  'Add Vehicle Success Year 2021',
#  'Add Vehicle Success Model Highlander',
#  'Add Vehicle Success Model X7',
#  'Add Vehicle Success Model Taurus',
#  'Wallet Opened',
#  'Add Vehicle Success Model Canyon',
#  'Add Vehicle Success Model MT07',
#  'Add Vehicle Success Model 3.2 TL',
#  'Add Vehicle Success Model E-350 Cargo',
#  'Add Vehicle Success Model QX80',
#  'Add Vehicle Success Model GX',
#  'Add Vehicle Success Model Corvette',
#  'Add Vehicle Success Model C-HR',
#  'Account History Transaction Details Type Auto Payment',
#  'Add Vehicle Success Model Durango',
#  'Add Vehicle Success Model Grand Cherokee',
#  'Add Vehicle Success Model Frontier',
#  'Add Payment Method Success Tokenized Pay Google Pay',
#  'Add Vehicle Success Make Jaguar',
#  'Add Vehicle Success Model Sprinter 2500 Cargo',
#  'Account History Transaction Details Navigated From account_history',
#  'Add Vehicle Success Model Equinox',
#  'Add Vehicle Success Year 2018',
#  'Add Vehicle Success Model Prius V',
#  'Add Vehicle Success Year 1999',
#  'Add Vehicle Success Model Tahoe',
#  'Calculator Used Selected Route Type One',
#  'Add Vehicle Success Model Charger',
#  'Add Vehicle Success Model Datsun 280zx ',
#  'Add Vehicle Success Model F-350',
#  'Add Vehicle Success Model Range Rover Sport',
#  'Add Vehicle Success Year 1990',
#  'Add Vehicle Success Model Zephyr',
#  'Chat Conversation Opened From Menu',
#  'Add Vehicle Success Model Kona',
#  'Add Vehicle Success Model F-450 SD DRW',
#  'Add Vehicle Success Model TrailBlazer',
#  'Add Payment Method Success Promo code INFLUENCER2021',
#  'Add Vehicle Success Model Rogue',
#  'Add Vehicle Success Model Sonic',
#  'Chat Conversation Opened Transaction type Pro Plan Subscription',
#  'Add Vehicle Success Year 2003',
#  'Add Vehicle Success Model Ranger',
#  'Add Vehicle Success Model QX56',
#  'Add Vehicle Success Model Raptor',
#  'Add Vehicle Success Model Flex',
#  'Email Confirmation Success',
#  'Add Vehicle Success Rental state TX',
#  'Add Vehicle Success Make Yamaha',
#  'Add Vehicle Success Model T680',
#  'Add Vehicle Success Model Pickup',
#  'Add Payment Method Success Tokenized Pay ',
#  'Add Vehicle Success Model 4-series',
#  'Add Payment Method Success Payment Method Credit',
#  'Add Vehicle Success Model Town and Country',
#  'Add Vehicle Success Year 1996',
#  'Add Vehicle Success Model Silverado 1500',
#  'Add Vehicle Success Make Chevrolet',
#  'Chat Conversation Opened Transaction type OrderPayment',
#  'Add Vehicle Success Model 545',
#  'Add Vehicle Success Model GL-Class',
#  'Add Vehicle Success Model Rio',
#  'Add Vehicle Success Model GT-R',
#  'Add Vehicle Success Model Vanagon',
#  'Add Vehicle Success Model Sierra 1500',
#  'Add Vehicle Success Model Odyssey',
#  'Add Vehicle Success Model QX50',
#  'Add Vehicle Success Model Passport',
#  'Add Vehicle Success Make Cadillac',
#  'Add Vehicle Success Year 1993',
#  'Add Vehicle Success Model Sorento',
#  'Add Vehicle Success Model Ram 2500',
#  'Add Payment Method Success Payment Method Debit',
#  'Add Vehicle Success Model RAV4',
#  'Add Vehicle Success Year 1995',
#  'Add Vehicle Success Model Nautilus',
#  'Add Payment Method Success Promo code TST2022']

# %% [markdown]
# Dataframe for events

# %%
events_data = pd.DataFrame(index=unique_users, columns=unique_combinations)
events_data
# Out:
#                                  Add Vehicle Success Make RAM  \
# c95c777785faec8dd910d019d7278ebe                          NaN
# f344be2d9a042b7444f3cc5279e38ef1                          NaN
# e331ed81422d8fba55520a43a872e701                          NaN
# f6d930969a59cfb488ed4d126c7c856d                          NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                          NaN
# ...                                                       ...
# 6ebd67ba68c521c86d797a1c439d6de9                          NaN
# 833489856a3cc8840d47a2c1cadda36d                          NaN
# 679eba26c4e75e0afb178360becfa21b                          NaN
# d46dcb2f00b6243de8714b979d524634                          NaN
# 59e61796833e7e9edcb7796fac1688ba                          NaN
#
#                                  Add Vehicle Success Model RAV4 Hybrid  \
# c95c777785faec8dd910d019d7278ebe                                   NaN
# f344be2d9a042b7444f3cc5279e38ef1                                   NaN
# e331ed81422d8fba55520a43a872e701                                   NaN
# f6d930969a59cfb488ed4d126c7c856d                                   NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                                   NaN
# ...                                                                ...
# 6ebd67ba68c521c86d797a1c439d6de9                                   NaN
# 833489856a3cc8840d47a2c1cadda36d                                   NaN
# 679eba26c4e75e0afb178360becfa21b                                   NaN
# d46dcb2f00b6243de8714b979d524634                                   NaN
# 59e61796833e7e9edcb7796fac1688ba                                   NaN
# f6d930969a59cfb488ed4d126c7c856d                            NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                            NaN
# ...                                                         ...
# 6ebd67ba68c521c86d797a1c439d6de9                            NaN
# 833489856a3cc8840d47a2c1cadda36d                            NaN
# 679eba26c4e75e0afb178360becfa21b                            NaN
# d46dcb2f00b6243de8714b979d524634                            NaN
# 59e61796833e7e9edcb7796fac1688ba                            NaN
#
#                                  Add Vehicle Success Year 1995  \
# c95c777785faec8dd910d019d7278ebe                           NaN
# f344be2d9a042b7444f3cc5279e38ef1                           NaN
# e331ed81422d8fba55520a43a872e701                           NaN
# f6d930969a59cfb488ed4d126c7c856d                           NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                           NaN
# ...                                                        ...
# 6ebd67ba68c521c86d797a1c439d6de9                           NaN
# 833489856a3cc8840d47a2c1cadda36d                           NaN
# 679eba26c4e75e0afb178360becfa21b                           NaN
# d46dcb2f00b6243de8714b979d524634                           NaN
# 59e61796833e7e9edcb7796fac1688ba                           NaN
#
#                                  Add Vehicle Success Model Nautilus  \
# c95c777785faec8dd910d019d7278ebe                                NaN
# f344be2d9a042b7444f3cc5279e38ef1                                NaN
# e331ed81422d8fba55520a43a872e701                                NaN
# f6d930969a59cfb488ed4d126c7c856d                                NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                                NaN
# ...                                                             ...
# 6ebd67ba68c521c86d797a1c439d6de9                                NaN
# 833489856a3cc8840d47a2c1cadda36d                                NaN
# 679eba26c4e75e0afb178360becfa21b                                NaN
# d46dcb2f00b6243de8714b979d524634                                NaN
# 59e61796833e7e9edcb7796fac1688ba                                NaN
#
#                                  Add Payment Method Success Promo code TST2022
# c95c777785faec8dd910d019d7278ebe                                           NaN
# f344be2d9a042b7444f3cc5279e38ef1                                           NaN
# e331ed81422d8fba55520a43a872e701                                           NaN
# f6d930969a59cfb488ed4d126c7c856d                                           NaN
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                                           NaN
# ...                                                                        ...
# 6ebd67ba68c521c86d797a1c439d6de9                                           NaN
# 833489856a3cc8840d47a2c1cadda36d                                           NaN
# 679eba26c4e75e0afb178360becfa21b                                           NaN
# d46dcb2f00b6243de8714b979d524634                                           NaN
# 59e61796833e7e9edcb7796fac1688ba                                           NaN
#
# [3540 rows x 662 columns]

# %% [markdown]
# Fill the events_data dataframe

# %%
for user in unique_users:
    user_data = data[data['userid'] == user]
    user_features = []
    for item in user_data.iloc:
        event = item['event_name']
        event_attributes = json.loads(item['event_attributes'])
        
        if len(event_attributes.keys()) > 0:
            for key in event_attributes.keys():
                if key not in ['Id', 'Amount', 'Start Date', 'Renewal Date', 'End Date']:
                    feature = event + ' ' + key + ' ' + event_attributes[key]
                    if feature not in user_features:
                        user_features.append(feature)
                        events_data.loc[user][feature] = 1
                    else:
                        events_data.loc[user][feature] += 1
                elif key == 'Amount':
                    feature = event + ' ' + key
                    if feature not in user_features:
                        user_features.append(feature)
                        events_data.loc[user][feature] = float(event_attributes[key])
                    else:
                        events_data.loc[user][feature] += float(event_attributes[key])
        else:
            if event not in user_features:
                user_features.append(event)
                events_data.loc[user][event] = 1
            else:
                events_data.loc[user][event] += 1

# %%
events_data = events_data.replace('', 0).fillna(0)

events_data['Transaction Refund Amount'].sum()

len(events_data.columns)
# Out:
# 662

# %% [markdown]
# Merging dataframes with events features and user features

# %%
clean_data = pd.merge(events_data, user_properties, left_index=True, right_index=True)
clean_data
# Out:
#                                   Add Vehicle Success Make RAM  \
# c95c777785faec8dd910d019d7278ebe                             0
# f344be2d9a042b7444f3cc5279e38ef1                             0
# e331ed81422d8fba55520a43a872e701                             0
# f6d930969a59cfb488ed4d126c7c856d                             0
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                             0
# ...                                                        ...
# 6ebd67ba68c521c86d797a1c439d6de9                             0
# 833489856a3cc8840d47a2c1cadda36d                             0
# 679eba26c4e75e0afb178360becfa21b                             0
# d46dcb2f00b6243de8714b979d524634                             0
# 59e61796833e7e9edcb7796fac1688ba                             0
#
#                                   Add Vehicle Success Model RAV4 Hybrid  \
# c95c777785faec8dd910d019d7278ebe                                      0
# f344be2d9a042b7444f3cc5279e38ef1                                      0
# e331ed81422d8fba55520a43a872e701                                      0
# f6d930969a59cfb488ed4d126c7c856d                                      0
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                                      0
# ...                                                                 ...
# 6ebd67ba68c521c86d797a1c439d6de9                                      0
# 833489856a3cc8840d47a2c1cadda36d                                      0
# 679eba26c4e75e0afb178360becfa21b                                      0
# d46dcb2f00b6243de8714b979d524634                                      0
# 59e61796833e7e9edcb7796fac1688ba                                      0
#
#                                   Add Vehicle Success Model Q60  \
# c95c777785faec8dd910d019d7278ebe                              0
# f344be2d9a042b7444f3cc5279e38ef1                              0
# e331ed81422d8fba55520a43a872e701                              0
# f6d930969a59cfb488ed4d126c7c856d                              0
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                              0
# ...                                                         ...
# 6ebd67ba68c521c86d797a1c439d6de9                              0
# 833489856a3cc8840d47a2c1cadda36d                              0
# 679eba26c4e75e0afb178360becfa21b                              0
# d46dcb2f00b6243de8714b979d524634                              0
# 59e61796833e7e9edcb7796fac1688ba                              0
#
#                                   Add Vehicle Success Model Camry  \
# c95c777785faec8dd910d019d7278ebe                                0
# f344be2d9a042b7444f3cc5279e38ef1                                0
# e331ed81422d8fba55520a43a872e701                                0
# f6d930969a59cfb488ed4d126c7c856d                                0
# 4ddc1ecfc4f1a31c22bb1346ae6c7c5b                                0
# ...                                                           ...
# 6ebd67ba68c521c86d797a1c439d6de9                                0
# 833489856a3cc8840d47a2c1cadda36d                                0
# 679eba26c4e75e0afb178360becfa21b                                0
# d46dcb2f00b6243de8714b979d524634                                0
# 59e61796833e7e9edcb7796fac1688ba                                0
#
#                                   Add Vehicle Success Model Wrangler  \
# c95c777785faec8dd910d019d7278ebe                                   0
# f344be2d9a042b7444f3cc5279e38ef1                                   0
# e331ed81422d8fba55520a43a872e701                                   0
# 078ae59f1ae79df514e846e5e51eca8b          CA             ios
# 3ba65939b03dd736b664863bd5e7eed4          CA         android
# 0c7170de11fabf2a805736938841cc8c          NJ             ios
# 5393129fdf773191f7b3de51b35bb15d          CA         android
# 3d49da0965533c33153bb65eb1b6d11d          CA             ios
# fc817111904f14d8868601ac1e1fedeb          IL         android
#
#                                   device_manufacture        device_model
# 1e78610bb127137ae210339776ac17d2               Apple          iPhone13,4
# b288242d86302c56eb49562a7d73a5f2               Apple          iPhone13,4
# 73a754cf72593344bcd2412c1c24975b               Apple          iPhone13,4
# 5085db2422dd457f81d595b1adbfe4a8            motorola  moto g play (2021)
# f57d02da24a18cd17a00aeddb46fa852               Apple          iPhone10,5
# f510005f651751e9dd7fcf15fab240c3               Apple          iPhone12,3
# c0b5d24cf149f2eca81332ead49a4108               Apple          iPhone13,3
# 270c14cfefa4e0dc596c90f6a8c6c363               Apple          iPhone13,3
# d263f69b765106b7790f098edb49f17b               Apple          iPhone12,5
# c952231e6ea12e2bdd6f735453422008               Apple          iPhone13,4
# fc9b74bab85fdc6cbdb5b965ca9f760f               Apple          iPhone12,1
# 5a90e9973c256c19c17b03bdda1c1fc4               Apple          iPhone12,1
# 2567193ff2ad4910e8b44dd1fc853195               Apple          iPhone14,3
# 375f680cd1242eb7bf9263dd5ba1fe6d               Apple          iPhone12,5
# 078ae59f1ae79df514e846e5e51eca8b               Apple          iPhone12,1
# 3ba65939b03dd736b664863bd5e7eed4             samsung           SM-J737T1
# 0c7170de11fabf2a805736938841cc8c               Apple          iPhone13,2
# 5393129fdf773191f7b3de51b35bb15d             samsung           SM-G998U1
# 3d49da0965533c33153bb65eb1b6d11d               Apple          iPhone13,2
# fc817111904f14d8868601ac1e1fedeb             samsung            SM-A326U
#
# [20 rows x 666 columns]

# %% [markdown]
# Some users have canceled the subscription more than 1 time (2, to be precise). We will treat this as a binary classification problem, therefore we will fill this values with 1

# %%
clean_data['Subscription Premium Cancel'] = clean_data['Subscription Premium Cancel']\
.apply(lambda row: 1 if row > 0 else 0)

# %%
X = clean_data.drop(['Subscription Premium Cancel'], axis=1)
y = clean_data['Subscription Premium Cancel']
print(X.shape)
print(y.shape)
# Out:
# (3540, 665)
# (3540,)

# %% [markdown]
# Applying one-hot encoding for categorical columns and scaling all the numerical values

# %%
categorical = [cname for cname in X.columns if X[cname].dtype == "object"]
numerical = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]

numerical_transformer = Pipeline(steps=[('scaler',
                                         StandardScaler())])
categorical_transformer = Pipeline(steps=[('onehot',
                                           OneHotEncoder(drop='if_binary',
                                            handle_unknown='ignore',
                                            sparse=False))])

ct = ColumnTransformer(transformers=[
        ('num', numerical_transformer, numerical),
        ('cat', categorical_transformer, categorical)],
        remainder='passthrough')

X = ct.fit_transform(X)
print(X.shape)
# Out:
# (3540, 1018)
# /Users/tylerdurden/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Spliting data (we do not use the test set)

# %%
# train = 80%
# test = 20%

X_train, X_valid, y_train, y_valid = train_test_split(X,y,stratify=y,train_size=0.8,test_size=0.2,random_state=69)

# %%
classes_weights = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

# Classifiers
classifiers = {
    "RandomForest" : RandomForestClassifier(random_state=0, class_weight='balanced'),
    "XGBoost" : XGBClassifier(random_state=0, use_label_encoder=False, eval_metric='logloss', tree_method='hist'),
    "LGBM" : LGBMClassifier(random_state=0),
    "CatBoost" : CatBoostClassifier(random_state=0, verbose=False)
}

# Grids for grid search
RF_grid = {'n_estimators': [200, 250, 300, 500, 1000],
        'max_depth': [8, 10, 12]}

boosted_grid = {'n_estimators': [50, 100, 150, 200],
        'max_depth': [4, 8, 12],
        'learning_rate': [0.05, 0.1]}

# Dictionary of all grids
grid = {
    "RandomForest" : RF_grid,
    "XGBoost" : boosted_grid,
    "LGBM" : boosted_grid,
    "CatBoost" : boosted_grid
}
# Out:
# /Users/tylerdurden/opt/miniconda3/envs/tf/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
i=0
clf_best_params=classifiers.copy()
valid_scores=pd.DataFrame({'Classifer':classifiers.keys(),
                           'ROC AUC score': np.zeros(len(classifiers)),
                           'Precision': np.zeros(len(classifiers)),
                           'Recall': np.zeros(len(classifiers)),
                           'F1-score': np.zeros(len(classifiers)), 
                           'PR-AUC': np.zeros(len(classifiers)), 
                           'Training time': np.zeros(len(classifiers))})

for key, classifier in classifiers.items():
    start = time.time()
    clf = GridSearchCV(estimator=classifier, param_grid=grid[key], n_jobs=-1, cv=None)

    # Train and score
    clf.fit(X_train, y_train)
    
    prediction = clf.predict(X_valid)
    valid_scores.iloc[i,1]=roc_auc_score(y_valid, prediction)
    valid_scores.iloc[i,2]=precision_score(y_valid, prediction)
    valid_scores.iloc[i,3]=recall_score(y_valid, prediction)
    valid_scores.iloc[i,4]=f1_score(y_valid, prediction)
    
    precision1, recall1, thresholds1 = precision_recall_curve(y_valid, prediction)
    valid_scores.iloc[i,5]=auc(recall1, precision1)

    # Save trained model
    clf_best_params[key]=clf.best_params_
    
    # Print iteration and training time
    stop = time.time()
    valid_scores.iloc[i,6]=np.round((stop - start)/60, 2)
    
    print('Model:', key)
    print('Training time (mins):', valid_scores.iloc[i,6])
    print('')
    i+=1
# Out:
# Model: RandomForest
# Training time (mins): 0.46
# /Users/tylerdurden/opt/miniconda3/envs/tf/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/tylerdurden/opt/miniconda3/envs/tf/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# Model: XGBoost
# Training time (mins): 0.22
#
# Model: LGBM
# Training time (mins): 0.04
#
# Model: CatBoost
# Training time (mins): 1.43

# %%
# Show results
valid_scores
# Out:
#       Classifer  ROC AUC score  Precision  Recall  F1-score    PR-AUC  \
# 0  RandomForest       0.871763   0.619048    0.78  0.690265  0.707292
# 1       XGBoost       0.812401   0.761905    0.64  0.695652  0.713664
# 2          LGBM       0.832401   0.772727    0.68  0.723404  0.737663
# 3      CatBoost       0.843921   0.813953    0.70  0.752688  0.767570
#
#    Training time
# 0           0.44
# 1           0.25
# 2           0.04
# 3           1.56

# %%
# Show best parameters from grid search
clf_best_params
# Out:
# {'RandomForest': {'max_depth': 12, 'n_estimators': 1000},
#  'XGBoost': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#  'LGBM': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#  'CatBoost': {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}}

# %%
# best parameters (tested multiple times)
model = RandomForestClassifier(random_state=0, class_weight='balanced', max_depth=10, n_estimators=1500)
model.fit(X_train, y_train)
prediction = model.predict(X_valid)

print('ROC AUC score:')
print(roc_auc_score(y_valid, prediction), "\n")
print('Precision:')
print(precision_score(y_valid, prediction), "\n")
print('Recall:')
print(recall_score(y_valid, prediction), "\n")
print('F1-score:')
print(f1_score(y_valid, prediction), "\n")
    
precision1, recall1, thresholds1 = precision_recall_curve(y_valid, prediction)
print('PR AUC score:')
print(auc(recall1, precision1), "\n")
# Out:
# ROC AUC score:
# 0.9149240121580546
#
# Precision:
# 0.5714285714285714
#
# Recall:
# 0.88
#
# F1-score:
# 0.6929133858267715
#
# PR AUC score:
# 0.7299515738498789

# %% [markdown]
# The best classifier is **RandomForest**, because we need to maximize **recall** (it is important to identify more positive cases, even if we mislabel some negative ones as positive: we don't want users to cancel the subscription). Also, it has a higher **ROC AUC score** and, moreover, a higher **precision-recall AUC** score (an important metric for us because we are more interested in **positive** cases).

# %%
{'RandomForest': {'max_depth': [10], 'n_estimators': [1000]},
 'XGBoost': {'learning_rate': [0.1], 'max_depth': [4], 'n_estimators': [100]},
 'LGBM': {'learning_rate': [0.1], 'max_depth': [4], 'n_estimators': [100]},
 'CatBoost': {'learning_rate': [0.1], 'max_depth': [12], 'n_estimators': [50]}}

# %%
for col, val in sorted(
                zip(clean_data.drop(['Subscription Premium Cancel'], axis=1).columns,model.feature_importances_),
                key=lambda x:x[1],
                reverse=True,)[:100]:
    print(f"{col:10} - {val:10.3f}")
# Out:
# Chat Conversation Started -      0.148
# Subscription Premium Membership Type Monthly -      0.113
# Chat Conversation Opened From Menu -      0.088
# Wallet Opened -      0.069
# Add Payment Method Success Promo code  -      0.041
# Transaction Refund Amount -      0.041
# Account History Transaction Details Type Auto Payment -      0.033
# Add Payment Method Success Payment Method Debit -      0.032
# Account History Transaction Details Status Paid -      0.024
# Account History Transaction Details Navigated From account_history -      0.022
# Account History Transaction Details Type Pro Plan Subscription -      0.022
# Order Premium Membership True -      0.020
# Add Payment Method Success Tokenized Pay  -      0.019
# Add Vehicle Success Temporary false -      0.016
# Add Payment Method Success Payment Method PayPal -      0.013
# Chat Conversation Opened Transaction type  -      0.012
# Account History Transaction Details Navigated From Account History -      0.012
# Add Payment Method Success Tokenized Pay Apple Pay -      0.010
# Calculator View -      0.010
# Add Payment Method Success Payment Method Credit -      0.009
# Chat Conversation Opened From Transaction Details -      0.008
# Add Payment Method Success Tokenized Pay Google Pay -      0.008
# Account History Transaction Details Status Pending -      0.007
# Add Vehicle Success Rental State  -      0.006
# Subscription Premium Renew Membership Type Yearly -      0.006
# Account History Transaction Details Type Order -      0.005
# Sign Out Type Manual -      0.005
# Add Vehicle Success Temporary true -      0.004
# Add Vehicle Success Color Black -      0.004
# Subscription Premium Renew Membership Type Monthly -      0.004
# Chat Conversation Opened Transaction type Pro Plan Subscription -      0.003
# Add Vehicle Success Year 2019 -      0.003
# Chat Conversation Opened From Dashboard -      0.003
# Add Vehicle Success Rental State CA -      0.003
# Add Payment Method Success Payment Method Venmo -      0.003
# Chat Conversation Opened Transaction type AutoPayment -      0.003
# Add Vehicle Success Make Ford -      0.003
# Sign Out Type Auto -      0.003
# Order Premium Membership False -      0.002
# Sign Up Success Method Google -      0.002
# Add Vehicle Success Rental State TX -      0.002
# Add Vehicle Success Color White -      0.002
# Sign Up Success Method Email -      0.002
# Add Vehicle Success Color Red -      0.002
# Add Vehicle Break -      0.002
# Add Vehicle Success Color Silver -      0.002
# Add Vehicle Success Year 2021 -      0.002
# Account History Transaction Details Type Violation Transaction -      0.002
# Email Confirmation Success Required true -      0.002
# Add Vehicle Success Color Gray -      0.002
# Add Payment Method Failed Error Code ERROR-16010 -      0.002
# Add Vehicle Success Year 2020 -      0.002
# Add Payment Method Failed Error Message Card is debit but credit is required. -      0.002
# Add Vehicle Success Make Nissan -      0.001
# Add Vehicle Success Year 2018 -      0.001
# Add Vehicle Success Rental state  -      0.001
# Account Setup Profile Skip Screen Address -      0.001
# Add Vehicle Success Model Fusion -      0.001
# Add Vehicle Success Make Honda -      0.001
# Sign Up Success Method Apple -      0.001
# Add Vehicle Success Make Toyota -      0.001
# Add Payment Method Failed Payment Method Credit Card -      0.001
# Chat Conversation Opened From Deeplink -      0.001
# Add Vehicle Success Year 2015 -      0.001
# Account Setup Profile Skip Screen Phone Number -      0.001
# Account Setup Skip -      0.001
# Add Vehicle Success Make Chevrolet -      0.001
# Account History Transaction Details Status Overdue -      0.001
# Email Confirmation Success -      0.001
# Account History Transaction Details Type Forced Payment -      0.001
# Sign Up Success Method Facebook -      0.001
# Add Vehicle Success Make Jeep -      0.001
# Chat Conversation Opened Transaction type OrderAlert -      0.001
# Calculator Used Google Map Installed true -      0.001
# Add Vehicle Success Year 2022 -      0.001
# Account Setup Profile Skip Screen Phone number -      0.001
# Add Vehicle Success Color Blue -      0.001
# Add Vehicle Success Year 2017 -      0.001
# Add Vehicle Success Year 2016 -      0.001
# Add Vehicle Success Model Camry -      0.001
# Calculator Used Selected Route Type One -      0.001
# Add Vehicle Success Make Kia -      0.001
# Add Vehicle Success Make Subaru -      0.001
# Add Vehicle Success Year 2012 -      0.001
# Add Vehicle Success Year 2014 -      0.001
# Add Vehicle Success Make BMW -      0.001
# Add Vehicle Success Year 2011 -      0.001
# Add Vehicle Success Year 2013 -      0.001
# Add Vehicle Success Model Accord -      0.001
# Add Vehicle Success Model Pilot -      0.001
# Add Vehicle Success Make Mercedes-Benz -      0.001
# Add Vehicle Success Model Outback -      0.001
# Add Vehicle Success Model Versa -      0.001
# Add Vehicle Success Model Altima -      0.001
# Add Vehicle Success Year 2010 -      0.001
# Add Vehicle Success Model Civic -      0.001
# Add Vehicle Success Model Corolla -      0.001
# Add Vehicle Success Make Lexus -      0.001
# Account Setup Profile Skip Screen Name -      0.001
# Add Payment Method Failed Tokenized Pay Apple Pay -      0.001
