# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report,confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.python.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
data = pd.read_csv("iasa_df.csv")

# %%
# id column
data.insert(0, 'id', list(np.arange(1,len(data)+1)))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467832 entries, 0 to 1467831
# Data columns (total 64 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   id                          1467832 non-null  int64
#  1   total_sessions_day0         1466467 non-null  float64
#  2   total_sessions_day1         1466465 non-null  float64
#  3   total_sessions_day3         1466464 non-null  float64
#  4   total_sessions_day7         1466458 non-null  float64
#  5   chapters_finished_day0      1467832 non-null  int64
#  6   chapters_finished_day1      1467832 non-null  int64
#  7   chapters_finished_day3      1467832 non-null  int64
#  8   chapters_finished_day7      1467832 non-null  int64
#  9   chapters_opened_day0        1467832 non-null  int64
#  10  chapters_opened_day1        1467832 non-null  int64
#  11  chapters_opened_day3        1467832 non-null  int64
#  12  chapters_opened_day7        1467832 non-null  int64
#  13  chapters_closed_day0        1467832 non-null  int64
#  14  chapters_closed_day1        1467832 non-null  int64
#  15  chapters_closed_day3        1467832 non-null  int64
#  16  chapters_closed_day7        1467832 non-null  int64
#  17  diamonds_received_day0      1467832 non-null  int64
#  18  diamonds_received_day1      1467832 non-null  int64
#  19  diamonds_received_day3      1467832 non-null  int64
#  20  diamonds_received_day7      1467832 non-null  int64
#  21  diamonds_spent_day0         1467832 non-null  int64
#  22  diamonds_spent_day1         1467832 non-null  int64
#  23  diamonds_spent_day3         1467832 non-null  int64
#  24  diamonds_spent_day7         1467832 non-null  int64
#  25  tickets_spent_day0          1467832 non-null  int64
#  26  tickets_spent_day1          1467832 non-null  int64
#  27  tickets_spent_day3          1467832 non-null  int64
#  28  tickets_spent_day7          1467832 non-null  int64
#  29  retained_day1               1467832 non-null  int64
#  30  retained_day3               1467832 non-null  int64
#  31  retained_day7               1467832 non-null  int64
#  32  chapters_finished_session1  1467832 non-null  int64
#  33  chapters_finished_session3  1467832 non-null  int64
#  34  chapters_finished_session9  1467832 non-null  int64
#  35  chapters_opened_session1    1467832 non-null  int64
#  36  chapters_opened_session3    1467832 non-null  int64
#  37  chapters_opened_session9    1467832 non-null  int64
#  38  chapters_closed_session1    1467832 non-null  int64
#  39  chapters_closed_session3    1467832 non-null  int64
#  40  chapters_closed_session9    1467832 non-null  int64
#  41  diamonds_spent_session1     1467832 non-null  int64
#  42  diamonds_spent_session3     1467832 non-null  int64
#  43  diamonds_spent_session9     1467832 non-null  int64
#  44  tickets_spent_session1      1467832 non-null  int64
#  45  tickets_spent_session3      1467832 non-null  int64
#  46  tickets_spent_session9      1467832 non-null  int64
#  47  app_sub_ltv_day0            1467832 non-null  float64
#  48  app_sub_ltv_day1            1467832 non-null  float64
#  49  app_sub_ltv_day3            1467832 non-null  float64
#  50  app_iap_ltv_day0            1467832 non-null  float64
#  51  app_iap_ltv_day1            1467832 non-null  float64
#  52  app_iap_ltv_day3            1467832 non-null  float64
#  53  media_source                1467832 non-null  object
#  54  install_date                1467832 non-null  object
#  55  country_code                1467832 non-null  object
#  56  ad_ltv_day0                 1467832 non-null  float64
#  57  ad_ltv_day1                 1467832 non-null  float64
#  58  ad_ltv_day3                 1467832 non-null  float64
#  59  platform                    1467832 non-null  object
#  60  target_sub_ltv_day30        1467832 non-null  float64
#  61  target_iap_ltv_day30        1467832 non-null  float64
#  62  target_ad_ltv_day30         1467832 non-null  float64
#  63  target_full_ltv_day30       1467832 non-null  float64
# dtypes: float64(17), int64(43), object(4)
# memory usage: 716.7+ MB

# %%
# percentage of missing data
data.isnull().sum() / data.shape[0]*100
# Out:
# id                       0.000000
# total_sessions_day0      0.092994
# total_sessions_day1      0.093131
# total_sessions_day3      0.093199
# total_sessions_day7      0.093607
#                            ...
# platform                 0.000000
# target_sub_ltv_day30     0.000000
# target_iap_ltv_day30     0.000000
# target_ad_ltv_day30      0.000000
# target_full_ltv_day30    0.000000
# Length: 64, dtype: float64

# %%
# list of columns with missing data
nan_columns = data.columns[data.isna().any()]

# %%
# correlation for columns with missing data
data.corr(numeric_only = True)[nan_columns]
# Out:
#                             total_sessions_day0  total_sessions_day1  \
# id                                    -0.035440            -0.041747
# total_sessions_day0                    1.000000             0.893938
# total_sessions_day1                    0.893938             1.000000
# total_sessions_day3                    0.769550             0.921799
# total_sessions_day7                    0.645850             0.803469
# chapters_finished_day0                 0.468981             0.496851
# chapters_finished_day1                 0.524887             0.608194
# chapters_finished_day3                 0.499239             0.600400
# chapters_finished_day7                 0.465746             0.571321
# chapters_opened_day0                   0.476621             0.504584
# chapters_opened_day1                   0.530964             0.618101
# chapters_opened_day3                   0.504385             0.608795
# chapters_opened_day7                   0.469664             0.578059
# chapters_closed_day0                   0.346678             0.382089
# chapters_closed_day1                   0.438042             0.532923
# chapters_closed_day3                   0.422356             0.536611
# chapters_closed_day7                   0.391984             0.509192
# diamonds_received_day0                 0.136594             0.145585
# diamonds_received_day1                 0.227401             0.251381
# diamonds_received_day3                 0.245383             0.286532
# diamonds_received_day7                 0.269158             0.326285
# diamonds_spent_day0                    0.312013             0.327915
# diamonds_spent_day1                    0.418265             0.458623
# diamonds_spent_day3                    0.401999             0.466830
# diamonds_spent_day7                    0.376598             0.454350
# tickets_spent_day0                     0.453666             0.479506
# tickets_spent_day1                     0.522939             0.587770
# tickets_spent_day3                     0.503600             0.586160
# tickets_spent_day7                     0.474660             0.565276
# retained_day1                          0.341080             0.488591
# retained_day3                          0.273740             0.363041
# retained_day7                          0.226259             0.302314
# chapters_finished_session1             0.142782             0.171140
# chapters_finished_session3             0.249176             0.286303
# chapters_finished_session9             0.346815             0.400424
# chapters_opened_session1               0.128093             0.158871
# chapters_opened_session3               0.248799             0.287232
# chapters_opened_session9               0.349435             0.404843
# chapters_closed_session1               0.053216             0.074217
# chapters_closed_session3               0.131421             0.162117
# chapters_closed_session9               0.228419             0.280689
# diamonds_spent_session1                0.093352             0.112123
# diamonds_spent_session3                0.159084             0.181929
# diamonds_spent_session9                0.225327             0.259560
# tickets_spent_session1                 0.140507             0.167861
# tickets_spent_session3                 0.249776             0.284964
# tickets_spent_session9                 0.347640             0.397902
# app_sub_ltv_day0                       0.052455             0.050102
# app_sub_ltv_day1                       0.063054             0.067010
# app_sub_ltv_day3                       0.095049             0.103725
# app_iap_ltv_day0                       0.183620             0.189986
# app_iap_ltv_day1                       0.234805             0.249848
# app_iap_ltv_day3                       0.221960             0.245477
# ad_ltv_day0                            0.342789             0.403873
# ad_ltv_day1                            0.444414             0.490204
# ad_ltv_day3                            0.416697             0.480158
# target_sub_ltv_day30                   0.098371             0.115510
# target_iap_ltv_day30                   0.175402             0.204456
# target_ad_ltv_day30                    0.289222             0.354639
# target_full_ltv_day30                  0.195514             0.229247
#
#                             total_sessions_day3  total_sessions_day7
# id                                    -0.043610            -0.045110
# total_sessions_day0                    0.769550             0.645850
# total_sessions_day1                    0.921799             0.803469
# total_sessions_day3                    1.000000             0.932322
# total_sessions_day7                    0.932322             1.000000
# chapters_finished_day0                 0.472214             0.427647
# chapters_finished_day1                 0.579884             0.522936
# chapters_finished_day3                 0.634031             0.599333
# chapters_finished_day7                 0.630265             0.654373
# chapters_opened_day0                   0.480074             0.435721
# chapters_opened_day1                   0.590341             0.533621
# chapters_opened_day3                   0.644511             0.610796
# chapters_opened_day7                   0.638949             0.665280
# chapters_closed_day0                   0.383041             0.365931
# chapters_closed_day1                   0.524794             0.492865
# chapters_closed_day3                   0.597216             0.594200
# chapters_closed_day7                   0.598198             0.663371
# diamonds_received_day0                 0.140904             0.129694
# diamonds_received_day1                 0.237433             0.214756
# diamonds_received_day3                 0.304937             0.293392
# diamonds_received_day7                 0.368936             0.396554
# diamonds_spent_day0                    0.314558             0.289313
# diamonds_spent_day1                    0.429922             0.387395
# diamonds_spent_day3                    0.496566             0.476927
# diamonds_spent_day7                    0.513919             0.554077
# tickets_spent_day0                     0.454745             0.411431
# tickets_spent_day1                     0.556227             0.498847
# tickets_spent_day3                     0.609168             0.571052
# tickets_spent_day7                     0.612532             0.629438
# retained_day1                          0.483650             0.450035
# retained_day3                          0.487432             0.509961
# retained_day7                          0.382175             0.496037
# chapters_finished_session1             0.175278             0.167482
# chapters_finished_session3             0.288653             0.273307
# chapters_finished_session9             0.408688             0.392726
# chapters_opened_session1               0.165739             0.160753
# chapters_opened_session3               0.290647             0.276656
# chapters_opened_session9               0.414363             0.399779
# chapters_closed_session1               0.084010             0.088798
# chapters_closed_session3               0.175898             0.180804
# chapters_closed_session9               0.306706             0.318051
# diamonds_spent_session1                0.117225             0.115294
# diamonds_spent_session3                0.186335             0.180665
# diamonds_spent_session9                0.270162             0.267955
# tickets_spent_session1                 0.171962             0.164028
# tickets_spent_session3                 0.286066             0.269951
# tickets_spent_session9                 0.403889             0.386245
# app_sub_ltv_day0                       0.045288             0.042395
# app_sub_ltv_day1                       0.051553             0.041777
# app_sub_ltv_day3                       0.098212             0.091769
# app_iap_ltv_day0                       0.179415             0.163147
# app_iap_ltv_day1                       0.230959             0.205992
# app_iap_ltv_day3                       0.250672             0.234647
# ad_ltv_day0                            0.411247             0.395641
# ad_ltv_day1                            0.489787             0.460332
# ad_ltv_day3                            0.524156             0.524749
# target_sub_ltv_day30                   0.127230             0.136706
# target_iap_ltv_day30                   0.227049             0.250285
# target_ad_ltv_day30                    0.424468             0.502810
# target_full_ltv_day30                  0.256596             0.284833

# %%
# filling missing data
def clean(data, nan_columns):
    
    null_data = data[data.isnull().any(axis=1)]
    
    for col in nan_columns:
        null_data[col] = null_data.apply(
            lambda row: data[col].median()
            if np.isnan(row[col])
            else row[col], axis=1)
        
    for i in null_data['id']:
        data[data['id'] == i] = null_data
    
    return data

# %%
data = clean(data, nan_columns)
# Out:
# /var/folders/8r/80qp0xcx3p986rp4th0s50140000gn/T/ipykernel_4572/495063889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_data[col] = null_data.apply(
# /var/folders/8r/80qp0xcx3p986rp4th0s50140000gn/T/ipykernel_4572/495063889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_data[col] = null_data.apply(
# /var/folders/8r/80qp0xcx3p986rp4th0s50140000gn/T/ipykernel_4572/495063889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_data[col] = null_data.apply(
# /var/folders/8r/80qp0xcx3p986rp4th0s50140000gn/T/ipykernel_4572/495063889.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_data[col] = null_data.apply(

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467832 entries, 0 to 1467831
# Data columns (total 64 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   id                          1467832 non-null  int64
#  1   total_sessions_day0         1467832 non-null  float64
#  2   total_sessions_day1         1467832 non-null  float64
#  3   total_sessions_day3         1467832 non-null  float64
#  4   total_sessions_day7         1467832 non-null  float64
#  5   chapters_finished_day0      1467832 non-null  int64
#  6   chapters_finished_day1      1467832 non-null  int64
#  7   chapters_finished_day3      1467832 non-null  int64
#  8   chapters_finished_day7      1467832 non-null  int64
#  9   chapters_opened_day0        1467832 non-null  int64
#  10  chapters_opened_day1        1467832 non-null  int64
#  11  chapters_opened_day3        1467832 non-null  int64
#  12  chapters_opened_day7        1467832 non-null  int64
#  13  chapters_closed_day0        1467832 non-null  int64
#  14  chapters_closed_day1        1467832 non-null  int64
#  15  chapters_closed_day3        1467832 non-null  int64
#  16  chapters_closed_day7        1467832 non-null  int64
#  17  diamonds_received_day0      1467832 non-null  int64
#  18  diamonds_received_day1      1467832 non-null  int64
#  19  diamonds_received_day3      1467832 non-null  int64
#  20  diamonds_received_day7      1467832 non-null  int64
#  21  diamonds_spent_day0         1467832 non-null  int64
#  22  diamonds_spent_day1         1467832 non-null  int64
#  23  diamonds_spent_day3         1467832 non-null  int64
#  24  diamonds_spent_day7         1467832 non-null  int64
#  25  tickets_spent_day0          1467832 non-null  int64
#  26  tickets_spent_day1          1467832 non-null  int64
#  27  tickets_spent_day3          1467832 non-null  int64
#  28  tickets_spent_day7          1467832 non-null  int64
#  29  retained_day1               1467832 non-null  int64
#  30  retained_day3               1467832 non-null  int64
#  31  retained_day7               1467832 non-null  int64
#  32  chapters_finished_session1  1467832 non-null  int64
#  33  chapters_finished_session3  1467832 non-null  int64
#  34  chapters_finished_session9  1467832 non-null  int64
#  35  chapters_opened_session1    1467832 non-null  int64
#  36  chapters_opened_session3    1467832 non-null  int64
#  37  chapters_opened_session9    1467832 non-null  int64
#  38  chapters_closed_session1    1467832 non-null  int64
#  39  chapters_closed_session3    1467832 non-null  int64
#  40  chapters_closed_session9    1467832 non-null  int64
#  41  diamonds_spent_session1     1467832 non-null  int64
#  42  diamonds_spent_session3     1467832 non-null  int64
#  43  diamonds_spent_session9     1467832 non-null  int64
#  44  tickets_spent_session1      1467832 non-null  int64
#  45  tickets_spent_session3      1467832 non-null  int64
#  46  tickets_spent_session9      1467832 non-null  int64
#  47  app_sub_ltv_day0            1467832 non-null  float64
#  48  app_sub_ltv_day1            1467832 non-null  float64
#  49  app_sub_ltv_day3            1467832 non-null  float64
#  50  app_iap_ltv_day0            1467832 non-null  float64
#  51  app_iap_ltv_day1            1467832 non-null  float64
#  52  app_iap_ltv_day3            1467832 non-null  float64
#  53  media_source                1467832 non-null  object
#  54  install_date                1467832 non-null  object
#  55  country_code                1467832 non-null  object
#  56  ad_ltv_day0                 1467832 non-null  float64
#  57  ad_ltv_day1                 1467832 non-null  float64
#  58  ad_ltv_day3                 1467832 non-null  float64
#  59  platform                    1467832 non-null  object
#  60  target_sub_ltv_day30        1467832 non-null  float64
#  61  target_iap_ltv_day30        1467832 non-null  float64
#  62  target_ad_ltv_day30         1467832 non-null  float64
#  63  target_full_ltv_day30       1467832 non-null  float64
# dtypes: float64(17), int64(43), object(4)
# memory usage: 716.7+ MB

# %%
# full = sub + iap + ad

y = data['target_full_ltv_day30'].copy().astype(int)

# Three independent targets
y_sub = data['target_sub_ltv_day30'].copy().astype(int)
y_iap = data['target_iap_ltv_day30'].copy().astype(int)
y_ad = data['target_ad_ltv_day30'].copy().astype(int)

# Maybe we shouldn't drop country_code and use it instead???

# TODO: deal with install_date

X = data.drop(['id',
               'target_full_ltv_day30',
               'target_sub_ltv_day30',
               'target_iap_ltv_day30',
               'target_ad_ltv_day30',
               'country_code',
               'install_date'], axis=1).copy()

# %%
# sub doesn't really need iap and ltv features and so on

X_sub = X.drop(['app_iap_ltv_day0',
                'app_iap_ltv_day1',
                'app_iap_ltv_day3',
                'ad_ltv_day0',
                'ad_ltv_day1',
                'ad_ltv_day3'], axis=1).copy()

X_iap = X.drop(['app_sub_ltv_day0',
                'app_sub_ltv_day1',
                'app_sub_ltv_day3',
                'ad_ltv_day0', 
                'ad_ltv_day1',
                'ad_ltv_day3'], axis=1).copy()

X_ad = X.drop(['app_sub_ltv_day0',
               'app_sub_ltv_day1',
               'app_sub_ltv_day3',
               'app_iap_ltv_day0', 
               'app_iap_ltv_day1',
               'app_iap_ltv_day3'], axis=1).copy()

# %%
# Indentify numerical and categorical columns
numerical_cols_sub = [cname for cname in X_sub.columns if X_sub[cname].dtype in ['int64', 'float64']]
categorical_cols_sub = [cname for cname in X_sub.columns if X_sub[cname].dtype == "object"]

numerical_cols_iap = [cname for cname in X_iap.columns if X_iap[cname].dtype in ['int64', 'float64']]
categorical_cols_iap = [cname for cname in X_iap.columns if X_iap[cname].dtype == "object"]

numerical_cols_ad = [cname for cname in X_ad.columns if X_ad[cname].dtype in ['int64', 'float64']]
categorical_cols_ad = [cname for cname in X_ad.columns if X_ad[cname].dtype == "object"]

# Scale numerical data to have mean=0 and variance=1
numerical_transformer = Pipeline(steps=[('scaler', StandardScaler())])

# One-hot encode categorical data
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(drop='if_binary', handle_unknown='ignore',sparse_output=False))])

# Combine preprocessing
ct_sub = ColumnTransformer(transformers=[
        ('num', numerical_transformer, numerical_cols_sub),
        ('cat', categorical_transformer, categorical_cols_sub)],
        remainder='passthrough')

ct_iap = ColumnTransformer(transformers=[
        ('num', numerical_transformer, numerical_cols_iap),
        ('cat', categorical_transformer, categorical_cols_iap)],
        remainder='passthrough')

ct_ad = ColumnTransformer(transformers=[
        ('num', numerical_transformer, numerical_cols_ad),
        ('cat', categorical_transformer, categorical_cols_ad)],
        remainder='passthrough')

# Apply preprocessing
X_sub = ct_sub.fit_transform(X_sub)
X_iap = ct_iap.fit_transform(X_iap)
X_ad = ct_ad.fit_transform(X_ad)

# Print new shape
print('Training set shape:', X_sub.shape)
# Out:
# Training set shape: (1467832, 75)

# %%
# Test-train-validation split for all targets
# train - 98%
# test - 1.5% 
# valid - 0.5% 

# sub 
X_train_sub, X_test_sub, y_train_sub, y_test_sub = train_test_split(X_sub, y_sub, test_size = 0.02, random_state=69)
X_valid_sub, X_test_sub, y_valid_sub, y_test_sub = train_test_split(X_test_sub, y_test_sub, test_size=0.25, random_state=69)

# iap
X_train_iap, X_test_iap, y_train_iap, y_test_iap = train_test_split(X_iap, y_iap, test_size = 0.02, random_state=69)
X_valid_iap, X_test_iap, y_valid_iap, y_test_iap = train_test_split(X_test_iap, y_test_iap, test_size=0.25, random_state=69)

# ad
X_train_ad, X_test_ad, y_train_ad, y_test_ad = train_test_split(X_ad, y_ad, test_size = 0.02, random_state=69)
X_valid_ad, X_test_ad, y_valid_ad, y_test_ad = train_test_split(X_test_ad, y_test_ad, test_size=0.25, random_state=69)

# %%
# SVC model 
# Try grid search ???
# It may take a lot of time

# Maybe we should train model on a small
# sample to decide which is better

svc_model_sub = SVC()
svc_model_sub.fit(X_train_sub,y_train_sub)

svc_model_iap = SVC()
svc_model_iap.fit(X_train_iap,y_train_iap)

svc_model_ad = SVC()
svc_model_ad.fit(X_train_ad,y_train_ad)

sub = svc_model_sub.predict(X_test_sub)
iap = svc_model_iap.predict(X_test_iap)
ad = svc_model_ad.predict(X_test_ad)

predictions = sub + iap + ad

# %%
print("Sub confusion matrix: ")
print(confusion_matrix(y_test, sub))

print("Iap confusion matrix: ")
print(confusion_matrix(y_test, iap))

print("Ad confusion matrix: ")
print(confusion_matrix(y_test, ad))

# %%
# Here I tried to create a simple neural network,
# doesn't work for now
def create_model():
    model = Sequential()

    model.add(Dense(53,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(27,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(14,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(7,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4,activation='relu'))
    model.add(Dense(1))
    
    model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=[RootMeanSquaredError()])
    
    return model

# %%
model_sub = create_model()
model_iap = create_model()
model_ad = create_model()

# %%
model_sub.fit(x=X_train_sub,
              y=y_train_sub,
              batch_size=32,
              epochs=3,
              validation_data=(X_valid_sub, y_valid_sub),
              verbose=1)

model_iap.fit(x=X_train_iap,
              y=y_train_iap.values,
              batch_size=32,
              epochs=3,
              validation_data=(X_valid_iap, y_valid_iap),
              verbose=1)

model_ad.fit(x=X_train_ad,
              y=y_train_ad,
              batch_size=32,
              epochs=3,
              validation_data=(X_valid_ad, y_valid_ad),
              verbose=1)
